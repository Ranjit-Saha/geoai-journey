# %%
# !pip install geopandas
# !pip install geodatasets

# %%
import geopandas as gpd
import geodatasets
import warnings
warnings.filterwarnings('ignore')

# %%
# This loads a low-res map of the world built into the library
world = gpd.read_file(geodatasets.get_path('naturalearth.land'))
world.plot(cmap='viridis', figsize=(10, 6))

print("System online: Map Render Successfully")
# Out:
# System online: Map Render Successfully

# %%
import geopandas as gpd
import geodatasets

# Load the low-res world map from the new sample library
world = gpd.read_file(geodatasets.get_path('naturalearth.land'))
world.plot(cmap='tab10', figsize=(10, 6))

print("System online: Map Rendered Successfully (2026 standards)")
# Out:
# System online: Map Rendered Successfully (2026 standards)
